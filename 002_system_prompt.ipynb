# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-5"

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": [{"type": "text", "text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": [{"type": "text", "text": text}]
    })


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
        }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params) 
    return message

# %%
messages = []

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.",
)
answer = chat(messages, system="You are a Python engineer who writes very concise code.")

for block in answer.content:
    if getattr(block, "type", None) == "text":
        print(block.text)
# Out:
# ```python
# def has_duplicates(s: str) -> bool:
#     return len(set(s)) != len(s)
# ```
#
# **Early-exit version** (avoids building a full set when a dupe appears early):
#
# ```python
# def has_duplicates(s: str) -> bool:
#     seen = set()
#     return any(c in seen or seen.add(c) for c in s)
# ```
#
# **If you want the offending characters:**
#
# ```python
# from collections import Counter
#
# def duplicates(s: str) -> set[str]:
#     return {c for c, n in Counter(s).items() if n > 1}
# ```
#
# Note: for case-insensitive checks, pass `s.casefold()`.
