# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-5"

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": [{"type": "text", "text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": [{"type": "text", "text": text}]
    })


def chat(messages):
    system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        system = system
    )
    return message

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages)

for block in answer.content:
    if getattr(block, "type", None) == "text":
        print(block.text)
# Out:
# Great question — let's work through it together rather than me just handing you the answer.
#
# **First, let's think about the goal.** When we "solve for x," we want to end up with `x = (some number)`. Right now, x has two things happening to it: it's being multiplied by 5, *and* 3 is being added.
#
# **Question 1:** To get x by itself, we need to undo those operations. Which one would you undo first — the "+3" or the "×5"?
#
# *Hint:* Think about the order of operations (PEMDAS) in reverse. When you're building the expression, you multiply first, then add. So when you're taking it apart, you go backwards.
#
# **Once you've decided:** Whatever operation you choose to undo, remember the golden rule — whatever you do to one side of the equation, you must do to the other side to keep it balanced.
#
# So try this:
# - What is the *opposite* of adding 3?
# - Apply that to **both** sides of `5x + 3 = 2`. What does the equation look like now?
#
# Give that a try and tell me what you get — then we'll tackle the second step together. 🙂
